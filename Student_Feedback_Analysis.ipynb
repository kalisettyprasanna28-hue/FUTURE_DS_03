# %%
from google.colab import files
uploaded = files.upload()
import pandas as pd
df=pd.read_csv('student_feedback.csv')
df.head()
# Out:
#      <input type="file" id="files-0e449dc0-b646-4e17-b7bb-6324972961ea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0e449dc0-b646-4e17-b7bb-6324972961ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Student ID', 'Well versed with the subject',
#        'Explains concepts in an understandable way', 'Use of presentations',
#        'Degree of difficulty of assignments', 'Solves doubts willingly',
#        'Structuring of the course',
#        'Provides support for students going above and beyond',
#        'Course recommendation based on relevance'],
#       dtype='object')

# %%
df_clean = clean_feedback_df(df)
df_clean.info()
df_clean.head(10)
# Out:
# Rating columns detected: ['well_versed_with_the_subject', 'explains_concepts_in_an_understandable_way', 'use_of_presentations', 'degree_of_difficulty_of_assignments', 'solves_doubts_willingly', 'structuring_of_the_course', 'provides_support_for_students_going_above_and_beyond', 'course_recommendation_based_on_relevance']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 11 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   student_id                                            1001 non-null   int64
#  1   well_versed_with_the_subject                          1001 non-null   int64
#  2   explains_concepts_in_an_understandable_way            1001 non-null   int64
#  3   use_of_presentations                                  1001 non-null   int64
# ...

# %%
# Visualization 1: Over all students Satisfaction Levels
import seaborn as s
import matplotlib.pyplot as p

plt.figure(figsize=(10,5))
sns.countplot(data=d, x='satisfaction_level', color='#00b050', edgecolor='black')
plt.title('Overall Student Satisfaction Levels', fontsize=14, fontweight='bold', color='green')
plt.xlabel('Satisfaction Level', fontsize=12)
plt.ylabel('Number of Students', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
#Correlation Heatmap between all rating questions
import seaborn as s
import matplotlib.pyplot as p

p.figure(figsize=(10,6))


num_cols = d.select_dtypes(include=['float64', 'int64'])
corr = num_cols.corr()

s.heatmap(corr, annot=True, cmap='Greens', fmt=".2f", linewidths=0.5)
p.title('Correlation Between Rating Questions', fontsize=14, fontweight='bold', color='green')
p.xlabel('Questions')
p.ylabel('Questions')
p.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,5))
sns.histplot(data=df_clean,x='degree_of_difficulty_of_assignments',bins=10)
plt.title('Distributions of Over Student ratings')
plt.xlabel('Average Ratings')
plt.ylabel("Number of Students")
plt.show()
